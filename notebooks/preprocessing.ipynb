# %% [markdown]
# ## Libraries

# %%
import sys
sys.path.append('..')
import pandas as pd
import numpy as np
from utils import preprocessing as prep

import warnings
pd.set_option('display.max_columns', None)
warnings.filterwarnings("ignore", "is_categorical_dtype")
warnings.filterwarnings("ignore", "use_inf_as_na")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_16031/1518311945.py in <module>
#       4 import numpy as np
#       5 from utils import preprocessing as prep
# ----> 6 from utils.preprocessing import workable_df
#       7
#       8
#
# ImportError: cannot import name 'workable_df' from 'utils.preprocessing' (/mnt/c/Users/madio/Documents/UniversiteitUtrecht/Master Applied Data Science/NS thesis/NS_TURNOVER_TIMES/notebooks/../utils/preprocessing.py)

# %% [markdown]
# ## Loading data

# %%
df_full = pd.read_csv('../data/Data_20230306_20230312.csv', low_memory = False)

# %% [markdown]
# ## Preprocessing data

# %%
# all current preprocessing steps
# set types
workable_df = df_full.copy()
workable_df = prep.set_types(workable_df)
workable_df = prep.calc_turnover(workable_df)
workable_df = prep.remove_unnecessary_rows(workable_df)
workable_df = prep.add_max_departure_time(workable_df)
workable_df = prep.calculate_signal_safe_delay(workable_df)
workable_df = prep.filter_outliers(workable_df)
workable_df = prep.categorise_combine_spilt(workable_df)
workable_df = prep.determine_daluren(workable_df)
workable_df = prep.calc_needed_turnover(workable_df)

workable_df.head()
# Out:
# /mnt/c/Users/madio/Documents/UniversiteitUtrecht/Master Applied Data Science/NS thesis/NS_TURNOVER_TIMES/notebooks/../utils/preprocessing.py:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nan["PLAN_TURNOVER_TIME"] = plan_turnover_time
# /mnt/c/Users/madio/Documents/UniversiteitUtrecht/Master Applied Data Science/NS thesis/NS_TURNOVER_TIMES/notebooks/../utils/preprocessing.py:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nan["REALIZED_TURNOVER_TIME"] = real_turnover_time
# ...

# %% [markdown]
# ## Save preprocessed data

# %%
# determining the name of the file
file_name = '../data/preprocessed_week_08-05-2024.xlsx'

# saving the excel
workable_df.to_csv(file_name)
